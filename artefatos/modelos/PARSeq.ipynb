# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas-azdias/Artistic-Text-Recognition/blob/main/artefatos/modelos/PARSeq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importações

# %%
# !pip install -q numpy==2.0.1
# !pip install -q torch==2.4.1 torchvision==0.19.1 torchaudio==2.4.1

# %%
# !pip install -q pytorch-lightning==2.5.0 lmdb fire hydra-core imgaug==0.4.0
# !pip install -q pyclipper pyyaml rapidfuzz gdown einops timm

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import pathlib
import PIL
import sys
import torch
import torchvision
import tqdm
import os

print("NumPy:", np.__version__)
print("Torch:", torch.__version__)
# Out:
# NumPy: 2.0.1
# Torch: 2.4.1+cu121

# %% [markdown]
# ## Obtendo dataset

# %% [markdown]
# ### Clonando dataset

# %%
# URL do repositório
dataset_url = "https://github.com/lucas-azdias/Artistic-Text-Recognition-Dataset.git"
dataset_path = pathlib.Path("/content/WordArt-V1.5")

# Clonar o repositório
# !rm -rf "{dataset_path}"
# !git clone "{dataset_url}" "{dataset_path}"
# Out:
# Cloning into '/content/WordArt-V1.5'...
# remote: Enumerating objects: 12063, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 12063 (delta 12), reused 14 (delta 0), pack-reused 12010 (from 1)
# Receiving objects: 100% (12063/12063), 1.29 GiB | 17.34 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# Updating files: 100% (12005/12005), done.

# %% [markdown]
# ### Carregando dataset

# %%
def load_data(base_path: pathlib.Path, name: str) -> tuple[list[pathlib.Path], list[str]]:
    labels_path = pathlib.Path(base_path, name, "labels.txt")

    image_paths = []
    classes = []

    with open(labels_path, "r") as f:
        for line in f:
            # Ex: "train_image\320.png Ford"
            splitted = line.strip().split(" ")
            path, label = splitted[0].replace("\\", "/"), " ".join(splitted[1:])

            # Ajustar o caminho para apontar para a pasta correta
            img_path = pathlib.Path(base_path, name, pathlib.Path(path))
            image_paths.append(img_path)
            classes.append(label)

    return image_paths, classes

train_images, train_labels = load_data(dataset_path, "train")
testA_images, testA_labels = load_data(dataset_path, "testA")
testB_images, testB_labels = load_data(dataset_path, "testB")

# %%
# URL do repositório
parseq_url = "https://github.com/baudm/parseq.git"
parseq_path = pathlib.Path("/content/parseq")

# Clonar o repositório
# !rm -rf "{parseq_path}"
# !git clone "{parseq_url}" "{parseq_path}"

if not str(parseq_path.absolute()) in sys.path:
    sys.path.append(str(parseq_path.absolute()))
# Out:
# Cloning into '/content/parseq'...
# remote: Enumerating objects: 612, done.
# remote: Counting objects: 100% (311/311), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 612 (delta 243), reused 193 (delta 193), pack-reused 301 (from 2)
# Receiving objects: 100% (612/612), 1.34 MiB | 38.13 MiB/s, done.
# Resolving deltas: 100% (344/344), done.

# %%
# !wget -q -O Miniconda.sh https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda.sh -b -f -p miniconda > /dev/null
# !rm Miniconda.sh

# !sudo rm -f /usr/local/bin/conda
# !ln -s /content/miniconda/bin/conda /usr/local/bin/conda

# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r

# %% [markdown]
# ## Dataset

# %%
# !python /content/parseq/tools/create_lmdb_dataset.py \
    "/content/WordArt-V1.5/train" \
    "/content/WordArt-V1.5/train/labels.txt" \
    "/content/data/train/real" \
    --checkValid=True
# Out:
# Written 1000 / 6000
# Written 2000 / 6000
# Written 3000 / 6000
# Written 4000 / 6000
# Written 5000 / 6000
# Written 6000 / 6000
# Created dataset with 6000 samples

# %%
# !python /content/parseq/tools/create_lmdb_dataset.py \
    "/content/WordArt-V1.5/testA" \
    "/content/WordArt-V1.5/testA/labels.txt" \
    "/content/data/val/real" \
    --checkValid=True
# Out:
# Written 1000 / 3000
# Written 2000 / 3000
# Written 3000 / 3000
# Created dataset with 3000 samples

# %%
# !python /content/parseq/tools/create_lmdb_dataset.py \
    "/content/WordArt-V1.5/testB" \
    "/content/WordArt-V1.5/testB/labels.txt" \
    "/content/data/test/real" \
    --checkValid=True
# Out:
# Written 1000 / 3000
# Written 2000 / 3000
# Written 3000 / 3000
# Created dataset with 3000 samples

# %% [markdown]
# ## Ambiente

# %%
# !conda env remove -n parseq -y -q > /dev/null 2>&1
# !conda create -n parseq python=3.10 -y -q > /dev/null 2>&1

# !conda run -n parseq pip install -q pip-tools
# !conda run -n parseq make torch-cu121 -C "{parseq_path}"
# !conda run -n parseq pip install -q -r "{parseq_path}/requirements/core.cu121.txt" -e {parseq_path}/.[bench,train,test,tune] --use-pep517
# Out:
# make: Entering directory '/content/parseq'
# Generating requirements/core.cu121.txt
# make: Leaving directory '/content/parseq'

# %% [markdown]
# ## Pesos

# %%
# !wget -O parseq.pt https://github.com/baudm/parseq/releases/download/v1.0.0/parseq-bb5792a6.pt
# Out:
# --2025-10-29 19:54:25--  https://github.com/baudm/parseq/releases/download/v1.0.0/parseq-bb5792a6.pt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/431325804/4f08baf8-bcc6-4f36-ab42-316b87e77ab5?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-29T20%3A43%3A50Z&rscd=attachment%3B+filename%3Dparseq-bb5792a6.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-29T19%3A42%3A59Z&ske=2025-10-29T20%3A43%3A50Z&sks=b&skv=2018-11-09&sig=rTUTW%2FqA9AXHx9jSaxT%2BKkipnSQQAzYfxNOXhXdnycc%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MTc2OTQ2NSwibmJmIjoxNzYxNzY3NjY1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.rNCzyI2zD9l2A9f_1SVnKpzHJTJsxcNobXtVB_mu23g&response-content-disposition=attachment%3B%20filename%3Dparseq-bb5792a6.pt&response-content-type=application%2Foctet-stream [following]
# --2025-10-29 19:54:26--  https://release-assets.githubusercontent.com/github-production-release-asset/431325804/4f08baf8-bcc6-4f36-ab42-316b87e77ab5?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-10-29T20%3A43%3A50Z&rscd=attachment%3B+filename%3Dparseq-bb5792a6.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-10-29T19%3A42%3A59Z&ske=2025-10-29T20%3A43%3A50Z&sks=b&skv=2018-11-09&sig=rTUTW%2FqA9AXHx9jSaxT%2BKkipnSQQAzYfxNOXhXdnycc%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MTc2OTQ2NSwibmJmIjoxNzYxNzY3NjY1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.rNCzyI2zD9l2A9f_1SVnKpzHJTJsxcNobXtVB_mu23g&response-content-disposition=attachment%3B%20filename%3Dparseq-bb5792a6.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95392675 (91M) [application/octet-stream]
# Saving to: ‘parseq.pt’
#
# parseq.pt           100%[===================>]  90.97M  40.0MB/s    in 2.3s
#
# 2025-10-29 19:54:28 (40.0 MB/s) - ‘parseq.pt’ saved [95392675/95392675]

# %% [markdown]
# # Fine Tuning

# %%
# !conda run -n parseq python "{parseq_path}/tune.py" --help
# Out:
# tune is powered by Hydra.
#
# == Configuration groups ==
# Compose your configuration from those groups (group=option)
#
# charset: 36_lowercase, 62_mixed-case, 94_full
# dataset: real, synth
# experiment: abinet, abinet-sv, crnn, parseq, parseq-patch16-224, parseq-tiny, trba, trbc, tune_abinet-lm, vitstr
# model: abinet, crnn, parseq, trba, vitstr
#
#
# == Config ==
# Override anything in the config (foo.bar=value)
#
# model:
#   _convert_: all
#   img_size:
#   - 32
#   - 128
#   max_label_length: 25
#   charset_train: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#   charset_test: 0123456789abcdefghijklmnopqrstuvwxyz
#   batch_size: 384
#   weight_decay: 0.0
#   warmup_pct: 0.075
#   name: parseq
#   _target_: strhub.models.parseq.system.PARSeq
#   patch_size:
#   - 4
#   - 8
#   embed_dim: 384
#   enc_num_heads: 6
#   enc_mlp_ratio: 4
#   enc_depth: 12
#   dec_num_heads: 12
#   dec_mlp_ratio: 4
#   dec_depth: 1
#   lr: 0.0007
#   perm_num: 6
#   perm_forward: true
#   perm_mirrored: true
#   dropout: 0.1
#   decode_ar: true
#   refine_iters: 1
# data:
#   _target_: strhub.data.module.SceneTextDataModule
#   root_dir: data
#   train_dir: real
#   batch_size: ${model.batch_size}
#   img_size: ${model.img_size}
#   charset_train: ${model.charset_train}
#   charset_test: ${model.charset_test}
#   max_label_length: ${model.max_label_length}
#   remove_whitespace: true
#   normalize_unicode: true
#   augment: true
#   num_workers: 2
# trainer:
#   _target_: pytorch_lightning.Trainer
#   _convert_: all
#   val_check_interval: 1000
#   max_epochs: 20
#   gradient_clip_val: 20
#   accelerator: gpu
#   devices: 1
# ckpt_path: null
# pretrained: null
# tune:
#   num_samples: 10
#   gpus_per_trial: 1
#   lr:
#     min: 0.0001
#     max: 0.002
#   resume_dir: null
#
#
# Powered by Hydra (https://hydra.cc)
# Use --hydra-help to view Hydra specific help

# %%
# %set_env HYDRA_FULL_ERROR=1
# Out:
# env: HYDRA_FULL_ERROR=1

# %%
# Função para alterar trechos dos arquivos alvos
def modify_target_files(target_files: list[pathlib.Path], old_texts: list[str], new_texts: list[str]) -> None:
    for target_file in target_files:
        text = target_file.read_text(encoding="utf-8")

        for old_text, new_text in zip(old_texts, new_texts):
            text = text.replace(
                old_text,
                new_text
            )

        target_file.write_text(text, encoding="utf-8")

# %%
# Modificando trechos necessários
modify_target_files(
    [
        parseq_path / "tune.py",
    ],
    [
        "from strhub.data.module import SceneTextDataModule\nfrom strhub.models.base import BaseSystem",
        "model: BaseSystem = hydra.utils.instantiate(config.model)\n    datamodule: SceneTextDataModule = hydra.utils.instantiate(config.data)",
    ],
    [
        "from strhub.data.module import SceneTextDataModule\nfrom torch import load\nfrom strhub.models.base import BaseSystem",
        "model: BaseSystem = hydra.utils.instantiate(config.model)\n    if config.pretrained is not None:\n        m = model.model if config.model._target_.endswith('PARSeq') else model\n        m.load_state_dict(load(config.pretrained))\n    datamodule: SceneTextDataModule = hydra.utils.instantiate(config.data)",
    ],
)

# %%
# !conda run -n parseq python "{parseq_path}/tune.py" \
trainer.max_epochs=5 \
trainer.val_check_interval=16 \
pretrained="/content/parseq.pt" \
tune.lr.max=0.0001 \
tune.lr.min=0.00001 \
model.dropout=0
# Out:
# [2025-10-29 20:08:49,367][strhub.data.dataset][INFO] - dataset root:	/content/data/train/real
# [2025-10-29 20:08:49,381][strhub.data.dataset][INFO] - 	lmdb:	.	num samples: 6000
# ╭────────────────────────────────────────────────────────╮
# │ Configuration for experiment     2025-10-29_20-08-49   │
# ├────────────────────────────────────────────────────────┤
# │ Search algorithm                 SearchGenerator       │
# │ Scheduler                        MedianStoppingRule    │
# │ Number of trials                 10                    │
# ╰────────────────────────────────────────────────────────╯
#
# View detailed results here: /content/ray_results/parseq/2025-10-29_20-08-49
# To visualize your results with TensorBoard, run: `tensorboard --logdir /content/ray_results/parseq/2025-10-29_20-08-49`
#
# Trial status: 1 PENDING
# Current time: 2025-10-29 20:08:52. Total running time: 0s
# Logical resource usage: 0/12 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:L4)
# ╭────────────────────────────────────────╮
# │ Trial name           status         lr │
# ├────────────────────────────────────────┤
# │ trainable_4639b809   PENDING    0.0001 │
# ╰────────────────────────────────────────╯
#
# Trial trainable_4639b809 started with configuration:
# ╭────────────────────────────────────────────╮
# │ Trial trainable_4639b809 config            │
# ├────────────────────────────────────────────┤
# │ lr                                  0.0001 │
# ╰────────────────────────────────────────────╯
#
# Trial status: 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:09:22. Total running time: 30s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# ╭────────────────────────────────────────╮
# │ Trial name           status         lr │
# ├────────────────────────────────────────┤
# │ trainable_4639b809   RUNNING    0.0001 │
# │ trainable_445331be   PENDING    1e-05  │
# ╰────────────────────────────────────────╯
#
# Trial trainable_445331be started with configuration:
# ╭───────────────────────────────────────────╮
# │ Trial trainable_445331be config           │
# ├───────────────────────────────────────────┤
# │ lr                                  1e-05 │
# ╰───────────────────────────────────────────╯
#
# Trial status: 1 PAUSED | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:09:52. Total running time: 1min 0s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=94.86978149414062 and params={'lr': 9.999999999999999e-05}
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status              lr     iter     total time (s)      loss       NED     accuracy │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_445331be   RUNNING    1e-05                                                                    │
# │ trainable_4639b809   PAUSED     0.0001             1            44.3274   4.49051   94.8698      84.4579 │
# │ trainable_fcd49ddc   PENDING    2.08311e-05                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Trial status: 1 PAUSED | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:10:22. Total running time: 1min 30s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=94.86978149414062 and params={'lr': 9.999999999999999e-05}
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status              lr     iter     total time (s)      loss       NED     accuracy │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_445331be   RUNNING    1e-05                                                                    │
# │ trainable_4639b809   PAUSED     0.0001             1            44.3274   4.49051   94.8698      84.4579 │
# │ trainable_fcd49ddc   PENDING    2.08311e-05                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial trainable_fcd49ddc started with configuration:
# ╭───────────────────────────────────────────╮
# │ Trial trainable_fcd49ddc config           │
# ├───────────────────────────────────────────┤
# │ lr                                  2e-05 │
# ╰───────────────────────────────────────────╯
#
# Trial status: 2 PAUSED | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:10:52. Total running time: 2min 0s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=94.86978149414062 and params={'lr': 9.999999999999999e-05}
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status              lr     iter     total time (s)      loss       NED     accuracy │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_fcd49ddc   RUNNING    2.08311e-05                                                              │
# │ trainable_4639b809   PAUSED     0.0001             1            44.3274   4.49051   94.8698      84.4579 │
# │ trainable_445331be   PAUSED     1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_bdae9971   PENDING    1.06731e-05                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial trainable_bdae9971 started with configuration:
# ╭───────────────────────────────────────────╮
# │ Trial trainable_bdae9971 config           │
# ├───────────────────────────────────────────┤
# │ lr                                  1e-05 │
# ╰───────────────────────────────────────────╯
#
# Trial status: 3 PAUSED | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:11:22. Total running time: 2min 30s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=94.86978149414062 and params={'lr': 9.999999999999999e-05}
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status              lr     iter     total time (s)      loss       NED     accuracy │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_bdae9971   RUNNING    1.06731e-05                                                              │
# │ trainable_4639b809   PAUSED     0.0001             1            44.3274   4.49051   94.8698      84.4579 │
# │ trainable_445331be   PAUSED     1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   PAUSED     2.08311e-05        1            44.762    4.71534   94.7724      84.2229 │
# │ trainable_96375eb2   PENDING    6.36365e-05                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial trainable_bdae9971 completed after 1 iterations at 2025-10-29 20:11:50. Total running time: 2min 58s
# ╭───────────────────────────────────────────────────────╮
# │ Trial trainable_bdae9971 result                       │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                 checkpoint_000000 │
# │ time_this_iter_s                             41.43915 │
# │ time_total_s                                 41.43915 │
# │ training_iteration                                  1 │
# │ NED                                          94.66725 │
# │ accuracy                                     84.05505 │
# │ loss                                          4.74301 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial trainable_96375eb2 started with configuration:
# ╭───────────────────────────────────────────╮
# │ Trial trainable_96375eb2 config           │
# ├───────────────────────────────────────────┤
# │ lr                                  6e-05 │
# ╰───────────────────────────────────────────╯
#
# Trial status: 3 PAUSED | 1 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:11:52. Total running time: 3min 0s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=94.86978149414062 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_96375eb2   RUNNING      6.36365e-05                                                              │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_4639b809   PAUSED       0.0001             1            44.3274   4.49051   94.8698      84.4579 │
# │ trainable_445331be   PAUSED       1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   PAUSED       2.08311e-05        1            44.762    4.71534   94.7724      84.2229 │
# │ trainable_a6b0145c   PENDING      2.35449e-05                                                              │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Trial status: 3 PAUSED | 1 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:12:22. Total running time: 3min 30s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=94.86978149414062 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_96375eb2   RUNNING      6.36365e-05                                                              │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_4639b809   PAUSED       0.0001             1            44.3274   4.49051   94.8698      84.4579 │
# │ trainable_445331be   PAUSED       1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   PAUSED       2.08311e-05        1            44.762    4.71534   94.7724      84.2229 │
# │ trainable_a6b0145c   PENDING      2.35449e-05                                                              │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Trial status: 3 PAUSED | 1 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:12:52. Total running time: 4min 0s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=94.86978149414062 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_96375eb2   RUNNING      6.36365e-05        1            41.6343   4.56965   94.8102      84.3572 │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_4639b809   PAUSED       0.0001             1            44.3274   4.49051   94.8698      84.4579 │
# │ trainable_445331be   PAUSED       1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   PAUSED       2.08311e-05        1            44.762    4.71534   94.7724      84.2229 │
# │ trainable_a6b0145c   PENDING      2.35449e-05                                                              │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial trainable_a6b0145c started with configuration:
# ╭───────────────────────────────────────────╮
# │ Trial trainable_a6b0145c config           │
# ├───────────────────────────────────────────┤
# │ lr                                  2e-05 │
# ╰───────────────────────────────────────────╯
#
# Trial status: 4 PAUSED | 1 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:13:22. Total running time: 4min 30s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=94.86978149414062 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_a6b0145c   RUNNING      2.35449e-05                                                              │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_4639b809   PAUSED       0.0001             1            44.3274   4.49051   94.8698      84.4579 │
# │ trainable_445331be   PAUSED       1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   PAUSED       2.08311e-05        1            44.762    4.71534   94.7724      84.2229 │
# │ trainable_96375eb2   PAUSED       6.36365e-05        2            83.5028   4.46212   94.8084      84.3572 │
# │ trainable_09e90a3e   PENDING      2.57694e-05                                                              │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Trial status: 4 PAUSED | 1 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:13:52. Total running time: 5min 0s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=94.86978149414062 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_a6b0145c   RUNNING      2.35449e-05                                                              │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_4639b809   PAUSED       0.0001             1            44.3274   4.49051   94.8698      84.4579 │
# │ trainable_445331be   PAUSED       1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   PAUSED       2.08311e-05        1            44.762    4.71534   94.7724      84.2229 │
# │ trainable_96375eb2   PAUSED       6.36365e-05        2            83.5028   4.46212   94.8084      84.3572 │
# │ trainable_09e90a3e   PENDING      2.57694e-05                                                              │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial trainable_a6b0145c completed after 1 iterations at 2025-10-29 20:13:57. Total running time: 5min 5s
# ╭───────────────────────────────────────────────────────╮
# │ Trial trainable_a6b0145c result                       │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                 checkpoint_000000 │
# │ time_this_iter_s                             42.54157 │
# │ time_total_s                                 42.54157 │
# │ training_iteration                                  1 │
# │ NED                                           94.7664 │
# │ accuracy                                     84.22289 │
# │ loss                                          4.69267 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial trainable_09e90a3e started with configuration:
# ╭───────────────────────────────────────────╮
# │ Trial trainable_09e90a3e config           │
# ├───────────────────────────────────────────┤
# │ lr                                  3e-05 │
# ╰───────────────────────────────────────────╯
#
# Trial status: 1 PENDING | 3 PAUSED | 2 TERMINATED | 1 RUNNING
# Current time: 2025-10-29 20:14:22. Total running time: 5min 30s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=94.86978149414062 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_09e90a3e   RUNNING      2.57694e-05                                                              │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_445331be   PAUSED       1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   PAUSED       2.08311e-05        1            44.762    4.71534   94.7724      84.2229 │
# │ trainable_96375eb2   PAUSED       6.36365e-05        2            83.5028   4.46212   94.8084      84.3572 │
# │ trainable_4639b809   PENDING      0.0001             1            44.3274   4.49051   94.8698      84.4579 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Trial status: 1 PENDING | 3 PAUSED | 2 TERMINATED | 1 RUNNING
# Current time: 2025-10-29 20:14:52. Total running time: 6min 0s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=94.86978149414062 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_09e90a3e   RUNNING      2.57694e-05        1            43.9631   4.69578   94.8378      84.29   │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_445331be   PAUSED       1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   PAUSED       2.08311e-05        1            44.762    4.71534   94.7724      84.2229 │
# │ trainable_96375eb2   PAUSED       6.36365e-05        2            83.5028   4.46212   94.8084      84.3572 │
# │ trainable_4639b809   PENDING      0.0001             1            44.3274   4.49051   94.8698      84.4579 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Trial status: 1 PENDING | 3 PAUSED | 2 TERMINATED | 1 RUNNING
# Current time: 2025-10-29 20:15:22. Total running time: 6min 30s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=94.86978149414062 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_09e90a3e   RUNNING      2.57694e-05        1            43.9631   4.69578   94.8378      84.29   │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_445331be   PAUSED       1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   PAUSED       2.08311e-05        1            44.762    4.71534   94.7724      84.2229 │
# │ trainable_96375eb2   PAUSED       6.36365e-05        2            83.5028   4.46212   94.8084      84.3572 │
# │ trainable_4639b809   PENDING      0.0001             1            44.3274   4.49051   94.8698      84.4579 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial trainable_4639b809 started with configuration:
# ╭────────────────────────────────────────────╮
# │ Trial trainable_4639b809 config            │
# ├────────────────────────────────────────────┤
# │ lr                                  0.0001 │
# ╰────────────────────────────────────────────╯
# Trial trainable_4639b809 started with configuration:
# ╭────────────────────────────────────────────╮
# │ Trial trainable_4639b809 config            │
# ├────────────────────────────────────────────┤
# │ lr                                  0.0001 │
# ╰────────────────────────────────────────────╯
#
# Trial trainable_fcd49ddc started with configuration:
# ╭───────────────────────────────────────────╮
# │ Trial trainable_fcd49ddc config           │
# ├───────────────────────────────────────────┤
# │ lr                                  2e-05 │
# ╰───────────────────────────────────────────╯
#
# Trial status: 1 PENDING | 1 ERROR | 1 RUNNING | 2 TERMINATED | 2 PAUSED
# Current time: 2025-10-29 20:15:52. Total running time: 7min 0s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: fcd49ddc with NED=95.45439910888672 and params={'lr': 2.08310500130881e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_fcd49ddc   RUNNING      2.08311e-05        2            48.2902   5.47206   95.4544      84.375  │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_96375eb2   PAUSED       6.36365e-05        2            83.5028   4.46212   94.8084      84.3572 │
# │ trainable_09e90a3e   PAUSED       2.57694e-05        2            88.1747   4.62555   94.8915      84.4243 │
# │ trainable_4639b809   PENDING      0.0001             3            53.7411   5.25302   95.3439      84.1146 │
# │ trainable_445331be   ERROR        1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Trial status: 1 PENDING | 1 ERROR | 1 RUNNING | 2 TERMINATED | 2 PAUSED
# Current time: 2025-10-29 20:16:22. Total running time: 7min 30s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: fcd49ddc with NED=95.45439910888672 and params={'lr': 2.08310500130881e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_fcd49ddc   RUNNING      2.08311e-05        2            48.2902   5.47206   95.4544      84.375  │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_96375eb2   PAUSED       6.36365e-05        2            83.5028   4.46212   94.8084      84.3572 │
# │ trainable_09e90a3e   PAUSED       2.57694e-05        2            88.1747   4.62555   94.8915      84.4243 │
# │ trainable_4639b809   PENDING      0.0001             3            53.7411   5.25302   95.3439      84.1146 │
# │ trainable_445331be   ERROR        1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial trainable_4639b809 started with configuration:
# ╭────────────────────────────────────────────╮
# │ Trial trainable_4639b809 config            │
# ├────────────────────────────────────────────┤
# │ lr                                  0.0001 │
# ╰────────────────────────────────────────────╯
#
# Trial trainable_4639b809 completed after 4 iterations at 2025-10-29 20:16:40. Total running time: 7min 48s
# ╭───────────────────────────────────────────────────────╮
# │ Trial trainable_4639b809 result                       │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                 checkpoint_000003 │
# │ time_this_iter_s                              3.42677 │
# │ time_total_s                                 57.16786 │
# │ training_iteration                                  4 │
# │ NED                                          95.34394 │
# │ accuracy                                     84.11459 │
# │ loss                                          5.25302 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial trainable_96375eb2 started with configuration:
# ╭───────────────────────────────────────────╮
# │ Trial trainable_96375eb2 config           │
# ├───────────────────────────────────────────┤
# │ lr                                  6e-05 │
# ╰───────────────────────────────────────────╯
#
# Trial status: 3 TERMINATED | 2 ERROR | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:16:52. Total running time: 8min 0s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=95.34394073486328 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_96375eb2   RUNNING      6.36365e-05        2            83.5028   4.46212   94.8084      84.3572 │
# │ trainable_4639b809   TERMINATED   0.0001             4            57.1679   5.25302   95.3439      84.1146 │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_09e90a3e   PENDING      2.57694e-05        2            88.1747   4.62555   94.8915      84.4243 │
# │ trainable_445331be   ERROR        1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   ERROR        2.08311e-05        3            97.8951   4.64477   94.8315      84.3572 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial trainable_09e90a3e started with configuration:
# ╭───────────────────────────────────────────╮
# │ Trial trainable_09e90a3e config           │
# ├───────────────────────────────────────────┤
# │ lr                                  3e-05 │
# ╰───────────────────────────────────────────╯
#
# Trial status: 3 TERMINATED | 2 ERROR | 1 PENDING | 1 RUNNING
# Current time: 2025-10-29 20:17:22. Total running time: 8min 30s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 09e90a3e with NED=95.35921478271484 and params={'lr': 2.576938954227893e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_09e90a3e   RUNNING      2.57694e-05        3            91.8522   5.37438   95.3592      84.375  │
# │ trainable_4639b809   TERMINATED   0.0001             4            57.1679   5.25302   95.3439      84.1146 │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_96375eb2   PENDING      6.36365e-05        3            89.5411   5.21747   95.2945      84.6354 │
# │ trainable_445331be   ERROR        1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   ERROR        2.08311e-05        3            97.8951   4.64477   94.8315      84.3572 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial trainable_09e90a3e completed after 4 iterations at 2025-10-29 20:17:50. Total running time: 8min 58s
# ╭───────────────────────────────────────────────────────╮
# │ Trial trainable_09e90a3e result                       │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                 checkpoint_000003 │
# │ time_this_iter_s                             52.11118 │
# │ time_total_s                                143.96342 │
# │ training_iteration                                  4 │
# │ NED                                          94.86362 │
# │ accuracy                                     84.45787 │
# │ loss                                          4.59394 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial trainable_96375eb2 started with configuration:
# ╭───────────────────────────────────────────╮
# │ Trial trainable_96375eb2 config           │
# ├───────────────────────────────────────────┤
# │ lr                                  6e-05 │
# ╰───────────────────────────────────────────╯
#
# Trial status: 4 TERMINATED | 2 ERROR | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:17:52. Total running time: 9min 0s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=95.34394073486328 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_96375eb2   RUNNING      6.36365e-05        3            89.5411   5.21747   95.2945      84.6354 │
# │ trainable_4639b809   TERMINATED   0.0001             4            57.1679   5.25302   95.3439      84.1146 │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_09e90a3e   TERMINATED   2.57694e-05        4           143.963    4.59394   94.8636      84.4579 │
# │ trainable_0aa29e00   PENDING      7.8436e-05                                                               │
# │ trainable_445331be   ERROR        1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   ERROR        2.08311e-05        3            97.8951   4.64477   94.8315      84.3572 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial trainable_96375eb2 completed after 4 iterations at 2025-10-29 20:17:55. Total running time: 9min 3s
# ╭───────────────────────────────────────────────────────╮
# │ Trial trainable_96375eb2 result                       │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                 checkpoint_000003 │
# │ time_this_iter_s                               3.3571 │
# │ time_total_s                                 92.89822 │
# │ training_iteration                                  4 │
# │ NED                                          95.29449 │
# │ accuracy                                     84.63541 │
# │ loss                                          5.21747 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial trainable_dc645c7f started with configuration:
# ╭───────────────────────────────────────────╮
# │ Trial trainable_dc645c7f config           │
# ├───────────────────────────────────────────┤
# │ lr                                  9e-05 │
# ╰───────────────────────────────────────────╯
#
# Trial status: 5 TERMINATED | 3 ERROR | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:18:22. Total running time: 9min 30s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=95.34394073486328 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_dc645c7f   RUNNING      8.75426e-05                                                              │
# │ trainable_4639b809   TERMINATED   0.0001             4            57.1679   5.25302   95.3439      84.1146 │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_96375eb2   TERMINATED   6.36365e-05        4            92.8982   5.21747   95.2945      84.6354 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_09e90a3e   TERMINATED   2.57694e-05        4           143.963    4.59394   94.8636      84.4579 │
# │ trainable_3d6a995d   PENDING      5.37635e-05                                                              │
# │ trainable_445331be   ERROR        1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   ERROR        2.08311e-05        3            97.8951   4.64477   94.8315      84.3572 │
# │ trainable_0aa29e00   ERROR        7.8436e-05                                                               │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Trial status: 5 TERMINATED | 3 ERROR | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:18:52. Total running time: 10min 0s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=95.34394073486328 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_dc645c7f   RUNNING      8.75426e-05        1            47.9868   4.50433   94.8113      84.5921 │
# │ trainable_4639b809   TERMINATED   0.0001             4            57.1679   5.25302   95.3439      84.1146 │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_96375eb2   TERMINATED   6.36365e-05        4            92.8982   5.21747   95.2945      84.6354 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_09e90a3e   TERMINATED   2.57694e-05        4           143.963    4.59394   94.8636      84.4579 │
# │ trainable_3d6a995d   PENDING      5.37635e-05                                                              │
# │ trainable_445331be   ERROR        1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   ERROR        2.08311e-05        3            97.8951   4.64477   94.8315      84.3572 │
# │ trainable_0aa29e00   ERROR        7.8436e-05                                                               │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Trial status: 5 TERMINATED | 3 ERROR | 1 RUNNING | 1 PENDING
# Current time: 2025-10-29 20:19:23. Total running time: 10min 30s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=95.34394073486328 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_dc645c7f   RUNNING      8.75426e-05        1            47.9868   4.50433   94.8113      84.5921 │
# │ trainable_4639b809   TERMINATED   0.0001             4            57.1679   5.25302   95.3439      84.1146 │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_96375eb2   TERMINATED   6.36365e-05        4            92.8982   5.21747   95.2945      84.6354 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_09e90a3e   TERMINATED   2.57694e-05        4           143.963    4.59394   94.8636      84.4579 │
# │ trainable_3d6a995d   PENDING      5.37635e-05                                                              │
# │ trainable_445331be   ERROR        1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   ERROR        2.08311e-05        3            97.8951   4.64477   94.8315      84.3572 │
# │ trainable_0aa29e00   ERROR        7.8436e-05                                                               │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial trainable_dc645c7f completed after 2 iterations at 2025-10-29 20:19:32. Total running time: 10min 40s
# ╭───────────────────────────────────────────────────────╮
# │ Trial trainable_dc645c7f result                       │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                 checkpoint_000001 │
# │ time_this_iter_s                             42.48012 │
# │ time_total_s                                 90.46689 │
# │ training_iteration                                  2 │
# │ NED                                          94.80083 │
# │ accuracy                                     84.69285 │
# │ loss                                           4.4189 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial trainable_3d6a995d started with configuration:
# ╭───────────────────────────────────────────╮
# │ Trial trainable_3d6a995d config           │
# ├───────────────────────────────────────────┤
# │ lr                                  5e-05 │
# ╰───────────────────────────────────────────╯
#
# Trial status: 6 TERMINATED | 3 ERROR | 1 RUNNING
# Current time: 2025-10-29 20:19:53. Total running time: 11min 0s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=95.34394073486328 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_3d6a995d   RUNNING      5.37635e-05                                                              │
# │ trainable_4639b809   TERMINATED   0.0001             4            57.1679   5.25302   95.3439      84.1146 │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_96375eb2   TERMINATED   6.36365e-05        4            92.8982   5.21747   95.2945      84.6354 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_09e90a3e   TERMINATED   2.57694e-05        4           143.963    4.59394   94.8636      84.4579 │
# │ trainable_dc645c7f   TERMINATED   8.75426e-05        2            90.4669   4.4189    94.8008      84.6928 │
# │ trainable_445331be   ERROR        1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   ERROR        2.08311e-05        3            97.8951   4.64477   94.8315      84.3572 │
# │ trainable_0aa29e00   ERROR        7.8436e-05                                                               │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Trial status: 6 TERMINATED | 3 ERROR | 1 RUNNING
# Current time: 2025-10-29 20:20:23. Total running time: 11min 31s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=95.34394073486328 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_3d6a995d   RUNNING      5.37635e-05        1            44.484    4.58852   94.881       84.3236 │
# │ trainable_4639b809   TERMINATED   0.0001             4            57.1679   5.25302   95.3439      84.1146 │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_96375eb2   TERMINATED   6.36365e-05        4            92.8982   5.21747   95.2945      84.6354 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_09e90a3e   TERMINATED   2.57694e-05        4           143.963    4.59394   94.8636      84.4579 │
# │ trainable_dc645c7f   TERMINATED   8.75426e-05        2            90.4669   4.4189    94.8008      84.6928 │
# │ trainable_445331be   ERROR        1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   ERROR        2.08311e-05        3            97.8951   4.64477   94.8315      84.3572 │
# │ trainable_0aa29e00   ERROR        7.8436e-05                                                               │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Trial status: 6 TERMINATED | 3 ERROR | 1 RUNNING
# Current time: 2025-10-29 20:20:53. Total running time: 12min 1s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=95.34394073486328 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_3d6a995d   RUNNING      5.37635e-05        1            44.484    4.58852   94.881       84.3236 │
# │ trainable_4639b809   TERMINATED   0.0001             4            57.1679   5.25302   95.3439      84.1146 │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_96375eb2   TERMINATED   6.36365e-05        4            92.8982   5.21747   95.2945      84.6354 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_09e90a3e   TERMINATED   2.57694e-05        4           143.963    4.59394   94.8636      84.4579 │
# │ trainable_dc645c7f   TERMINATED   8.75426e-05        2            90.4669   4.4189    94.8008      84.6928 │
# │ trainable_445331be   ERROR        1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   ERROR        2.08311e-05        3            97.8951   4.64477   94.8315      84.3572 │
# │ trainable_0aa29e00   ERROR        7.8436e-05                                                               │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Trial status: 6 TERMINATED | 3 ERROR | 1 RUNNING
# Current time: 2025-10-29 20:21:23. Total running time: 12min 31s
# Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:L4)
# Current best trial: 4639b809 with NED=95.34394073486328 and params={'lr': 9.999999999999999e-05}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name           status                lr     iter     total time (s)      loss       NED     accuracy │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_3d6a995d   RUNNING      5.37635e-05        2            87.9878   4.50068   94.8559      84.5586 │
# │ trainable_4639b809   TERMINATED   0.0001             4            57.1679   5.25302   95.3439      84.1146 │
# │ trainable_bdae9971   TERMINATED   1.06731e-05        1            41.4391   4.74301   94.6673      84.0551 │
# │ trainable_96375eb2   TERMINATED   6.36365e-05        4            92.8982   5.21747   95.2945      84.6354 │
# │ trainable_a6b0145c   TERMINATED   2.35449e-05        1            42.5416   4.69267   94.7664      84.2229 │
# │ trainable_09e90a3e   TERMINATED   2.57694e-05        4           143.963    4.59394   94.8636      84.4579 │
# │ trainable_dc645c7f   TERMINATED   8.75426e-05        2            90.4669   4.4189    94.8008      84.6928 │
# │ trainable_445331be   ERROR        1e-05              1            42.4305   4.73799   94.6871      84.1558 │
# │ trainable_fcd49ddc   ERROR        2.08311e-05        3            97.8951   4.64477   94.8315      84.3572 │
# │ trainable_0aa29e00   ERROR        7.8436e-05                                                               │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial trainable_3d6a995d completed after 3 iterations at 2025-10-29 20:21:45. Total running time: 12min 53s
# ╭───────────────────────────────────────────────────────╮
# │ Trial trainable_3d6a995d result                       │
# ├───────────────────────────────────────────────────────┤
# ...
# (trainable pid=12476) Restored on 172.28.0.12 from checkpoint: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_fcd49ddc_3_lr=0.0000_2025-10-29_20-09-40/checkpoint_000000)
# (trainable pid=12476) GPU available: True (cuda), used: True
# (trainable pid=12476) TPU available: False, using: 0 TPU cores
# (trainable pid=12476) IPU available: False, using: 0 IPUs
# (trainable pid=12476) HPU available: False, using: 0 HPUs
# (trainable pid=12476) Restoring states from the checkpoint path at /content/ray_results/parseq/2025-10-29_20-08-49/trainable_fcd49ddc_3_lr=0.0000_2025-10-29_20-09-40/checkpoint_000000/checkpoint
# (trainable pid=12476) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (trainable pid=12476) Loading `train_dataloader` to estimate number of stepping batches.
# (trainable pid=12476)
# (trainable pid=12476)   | Name  | Type   | Params
# (trainable pid=12476) ---------------------------------
# (trainable pid=12476) 0 | model | PARSeq | 23.8 M
# (trainable pid=12476) ---------------------------------
# (trainable pid=12476) 23.8 M    Trainable params
# (trainable pid=12476) 0         Non-trainable params
# (trainable pid=12476) 23.8 M    Total params
# (trainable pid=12476) 95.331    Total estimated model params size (MB)
# (trainable pid=12476) Restored all states from the checkpoint at /content/ray_results/parseq/2025-10-29_20-08-49/trainable_fcd49ddc_3_lr=0.0000_2025-10-29_20-09-40/checkpoint_000000/checkpoint
# (trainable pid=12476) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_fcd49ddc_3_lr=0.0000_2025-10-29_20-09-40/checkpoint_000001)
# (trainable pid=12476) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_fcd49ddc_3_lr=0.0000_2025-10-29_20-09-40/checkpoint_000002)
# (trainable pid=12476) Restored on 172.28.0.12 from checkpoint: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_4639b809_1_lr=0.0001_2025-10-29_20-08-52/checkpoint_000002)
# (trainable pid=12476) GPU available: True (cuda), used: True
# (trainable pid=12476) TPU available: False, using: 0 TPU cores
# (trainable pid=12476) IPU available: False, using: 0 IPUs
# (trainable pid=12476) HPU available: False, using: 0 HPUs
# (trainable pid=12476) Restoring states from the checkpoint path at /content/ray_results/parseq/2025-10-29_20-08-49/trainable_4639b809_1_lr=0.0001_2025-10-29_20-08-52/checkpoint_000002/checkpoint
# (trainable pid=12476) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (trainable pid=12476) Loading `train_dataloader` to estimate number of stepping batches.
# (trainable pid=12476)
# (trainable pid=12476)   | Name  | Type   | Params
# (trainable pid=12476) ---------------------------------
# (trainable pid=12476) 0 | model | PARSeq | 23.8 M
# (trainable pid=12476) ---------------------------------
# (trainable pid=12476) 23.8 M    Trainable params
# (trainable pid=12476) 0         Non-trainable params
# (trainable pid=12476) 23.8 M    Total params
# (trainable pid=12476) 95.331    Total estimated model params size (MB)
# (trainable pid=12476) Restored all states from the checkpoint at /content/ray_results/parseq/2025-10-29_20-08-49/trainable_4639b809_1_lr=0.0001_2025-10-29_20-08-52/checkpoint_000002/checkpoint
# [INFO 10-29 20:16:40] ax.service.ax_client: Completed trial 0 with data: {'NED': (95.343941, None)}.
# (trainable pid=12476) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_4639b809_1_lr=0.0001_2025-10-29_20-08-52/checkpoint_000003)
# 2025-10-29 20:16:42,852	ERROR tune_controller.py:1979 -- Could not re-use actor for trial trainable_fcd49ddc: Trainable runner reuse requires reset_config() to be implemented and return True.
# (trainable pid=12910) Restored on 172.28.0.12 from checkpoint: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_96375eb2_5_lr=0.0001_2025-10-29_20-11-08/checkpoint_000001)
# (trainable pid=12910) GPU available: True (cuda), used: True
# (trainable pid=12910) TPU available: False, using: 0 TPU cores
# (trainable pid=12910) IPU available: False, using: 0 IPUs
# (trainable pid=12910) HPU available: False, using: 0 HPUs
# (trainable pid=12910) You are using a CUDA device ('NVIDIA L4') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# (trainable pid=12910) Restoring states from the checkpoint path at /content/ray_results/parseq/2025-10-29_20-08-49/trainable_96375eb2_5_lr=0.0001_2025-10-29_20-11-08/checkpoint_000001/checkpoint
# (trainable pid=12910) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (trainable pid=12910) Loading `train_dataloader` to estimate number of stepping batches.
# (trainable pid=12910) /content/miniconda/envs/parseq/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (16) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# (trainable pid=12910)
# (trainable pid=12910)   | Name  | Type   | Params
# (trainable pid=12910) ---------------------------------
# (trainable pid=12910) 0 | model | PARSeq | 23.8 M
# (trainable pid=12910) ---------------------------------
# (trainable pid=12910) 23.8 M    Trainable params
# (trainable pid=12910) 0         Non-trainable params
# (trainable pid=12910) 23.8 M    Total params
# (trainable pid=12910) 95.331    Total estimated model params size (MB)
# (trainable pid=12910) Restored all states from the checkpoint at /content/ray_results/parseq/2025-10-29_20-08-49/trainable_96375eb2_5_lr=0.0001_2025-10-29_20-11-08/checkpoint_000001/checkpoint
# (trainable pid=12910) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_96375eb2_5_lr=0.0001_2025-10-29_20-11-08/checkpoint_000002)
# (trainable pid=12910) Restored on 172.28.0.12 from checkpoint: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_09e90a3e_7_lr=0.0000_2025-10-29_20-13-15/checkpoint_000001)
# (trainable pid=12910) GPU available: True (cuda), used: True
# (trainable pid=12910) TPU available: False, using: 0 TPU cores
# (trainable pid=12910) IPU available: False, using: 0 IPUs
# (trainable pid=12910) HPU available: False, using: 0 HPUs
# (trainable pid=12910) Restoring states from the checkpoint path at /content/ray_results/parseq/2025-10-29_20-08-49/trainable_09e90a3e_7_lr=0.0000_2025-10-29_20-13-15/checkpoint_000001/checkpoint
# (trainable pid=12910) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (trainable pid=12910) Loading `train_dataloader` to estimate number of stepping batches.
# (trainable pid=12910)
# (trainable pid=12910)   | Name  | Type   | Params
# (trainable pid=12910) ---------------------------------
# (trainable pid=12910) 0 | model | PARSeq | 23.8 M
# (trainable pid=12910) ---------------------------------
# (trainable pid=12910) 23.8 M    Trainable params
# (trainable pid=12910) 0         Non-trainable params
# (trainable pid=12910) 23.8 M    Total params
# (trainable pid=12910) 95.331    Total estimated model params size (MB)
# (trainable pid=12910) Restored all states from the checkpoint at /content/ray_results/parseq/2025-10-29_20-08-49/trainable_09e90a3e_7_lr=0.0000_2025-10-29_20-13-15/checkpoint_000001/checkpoint
# (trainable pid=12910) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_09e90a3e_7_lr=0.0000_2025-10-29_20-13-15/checkpoint_000002)
# [INFO 10-29 20:17:50] ax.service.ax_client: Completed trial 6 with data: {'NED': (94.863625, None)}.
# (trainable pid=12910) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_09e90a3e_7_lr=0.0000_2025-10-29_20-13-15/checkpoint_000003)
# /content/miniconda/envs/parseq/lib/python3.10/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# (trainable pid=12910) Restored on 172.28.0.12 from checkpoint: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_96375eb2_5_lr=0.0001_2025-10-29_20-11-08/checkpoint_000002)
# [INFO 10-29 20:17:51] ax.service.ax_client: Generated new trial 7 with parameters {'lr': 7.8e-05}.
# (trainable pid=12910) GPU available: True (cuda), used: True
# (trainable pid=12910) TPU available: False, using: 0 TPU cores
# (trainable pid=12910) IPU available: False, using: 0 IPUs
# (trainable pid=12910) HPU available: False, using: 0 HPUs
# (trainable pid=12910) Restoring states from the checkpoint path at /content/ray_results/parseq/2025-10-29_20-08-49/trainable_96375eb2_5_lr=0.0001_2025-10-29_20-11-08/checkpoint_000002/checkpoint
# (trainable pid=12910) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (trainable pid=12910) Loading `train_dataloader` to estimate number of stepping batches.
# (trainable pid=12910)
# (trainable pid=12910)   | Name  | Type   | Params
# (trainable pid=12910) ---------------------------------
# (trainable pid=12910) 0 | model | PARSeq | 23.8 M
# (trainable pid=12910) ---------------------------------
# (trainable pid=12910) 23.8 M    Trainable params
# (trainable pid=12910) 0         Non-trainable params
# (trainable pid=12910) 23.8 M    Total params
# (trainable pid=12910) 95.331    Total estimated model params size (MB)
# (trainable pid=12910) Restored all states from the checkpoint at /content/ray_results/parseq/2025-10-29_20-08-49/trainable_96375eb2_5_lr=0.0001_2025-10-29_20-11-08/checkpoint_000002/checkpoint
# [INFO 10-29 20:17:55] ax.service.ax_client: Completed trial 4 with data: {'NED': (95.294495, None)}.
# (trainable pid=12910) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_96375eb2_5_lr=0.0001_2025-10-29_20-11-08/checkpoint_000003)
# 2025-10-29 20:17:57,373	ERROR tune_controller.py:1979 -- Could not re-use actor for trial trainable_0aa29e00: Trainable runner reuse requires reset_config() to be implemented and return True.
# /content/miniconda/envs/parseq/lib/python3.10/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 10-29 20:17:58] ax.service.ax_client: Generated new trial 8 with parameters {'lr': 8.8e-05}.
# /content/miniconda/envs/parseq/lib/python3.10/site-packages/ax/core/data.py:284: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 10-29 20:18:02] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 10-29 20:18:04] ax.service.ax_client: Generated new trial 9 with parameters {'lr': 5.4e-05}.
# (trainable pid=13376) You are using a CUDA device ('NVIDIA L4') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# (trainable pid=13376) GPU available: True (cuda), used: True
# (trainable pid=13376) TPU available: False, using: 0 TPU cores
# (trainable pid=13376) IPU available: False, using: 0 IPUs
# (trainable pid=13376) HPU available: False, using: 0 HPUs
# (trainable pid=13376) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (trainable pid=13376) Loading `train_dataloader` to estimate number of stepping batches.
# (trainable pid=13376) /content/miniconda/envs/parseq/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (16) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# (trainable pid=13376)
# (trainable pid=13376)   | Name  | Type   | Params
# (trainable pid=13376) ---------------------------------
# (trainable pid=13376) 0 | model | PARSeq | 23.8 M
# (trainable pid=13376) ---------------------------------
# (trainable pid=13376) 23.8 M    Trainable params
# (trainable pid=13376) 0         Non-trainable params
# (trainable pid=13376) 23.8 M    Total params
# (trainable pid=13376) 95.331    Total estimated model params size (MB)
# (trainable pid=13376) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_dc645c7f_9_lr=0.0001_2025-10-29_20-17-58/checkpoint_000000)
# [INFO 10-29 20:19:32] ax.service.ax_client: Completed trial 8 with data: {'NED': (94.800827, None)}.
# (trainable pid=13376) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_dc645c7f_9_lr=0.0001_2025-10-29_20-17-58/checkpoint_000001)
# (trainable pid=13376) GPU available: True (cuda), used: True
# (trainable pid=13376) TPU available: False, using: 0 TPU cores
# (trainable pid=13376) IPU available: False, using: 0 IPUs
# (trainable pid=13376) HPU available: False, using: 0 HPUs
# (trainable pid=13376) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (trainable pid=13376) Loading `train_dataloader` to estimate number of stepping batches.
# (trainable pid=13376)
# (trainable pid=13376)   | Name  | Type   | Params
# (trainable pid=13376) ---------------------------------
# (trainable pid=13376) 0 | model | PARSeq | 23.8 M
# (trainable pid=13376) ---------------------------------
# (trainable pid=13376) 23.8 M    Trainable params
# (trainable pid=13376) 0         Non-trainable params
# (trainable pid=13376) 23.8 M    Total params
# (trainable pid=13376) 95.331    Total estimated model params size (MB)
# (trainable pid=13376) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_3d6a995d_10_lr=0.0001_2025-10-29_20-18-04/checkpoint_000000)
# (trainable pid=13376) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_3d6a995d_10_lr=0.0001_2025-10-29_20-18-04/checkpoint_000001)
# [INFO 10-29 20:21:45] ax.service.ax_client: Completed trial 9 with data: {'NED': (94.850723, None)}.
# (trainable pid=13376) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/content/ray_results/parseq/2025-10-29_20-08-49/trainable_3d6a995d_10_lr=0.0001_2025-10-29_20-18-04/checkpoint_000002)
# 2025-10-29 20:21:45,286	ERROR tune.py:1038 -- Trials did not complete: [trainable_445331be, trainable_fcd49ddc, trainable_0aa29e00]
# 2025-10-29 20:21:45,302	WARNING experiment_analysis.py:193 -- Failed to fetch metrics for 1 trial(s):
# - trainable_0aa29e00: FileNotFoundError('Could not fetch metrics for trainable_0aa29e00: both result.json and progress.csv were not found at /content/ray_results/parseq/2025-10-29_20-08-49/trainable_0aa29e00_8_lr=0.0001_2025-10-29_20-17-51')

# %% [markdown]
# # Execução

# %%
# Modificando trechos necessários
modify_target_files(
    [
        parseq_path / "read.py",
    ],
    [
        "import argparse",
        "nargs='+', ",
        "for fname in args.images:",
        "Image.open(fname)",
        "print(f'{fname}: {pred[0]}')",
    ],
    [
        "import argparse\nfrom pathlib import Path",
        "",
        "text = \"\"\n    imgs = Path(args.images)\n    for fname in (imgs.rglob(\"*\") if imgs.is_dir() else [imgs]):",
        "Image.open(fname.absolute())",
        "text += f\"{fname}\t{pred[0]}\t{p[0].tolist()[:-1]}\\n\"\n    print(text)\n    open(\"outputs.txt\", \"w\").write(text)",
    ],
)

# %%
import re

normalize = lambda s: re.sub(r'[^a-z0-9]', '', s.lower())
compare = lambda a, b: normalize(a) == normalize(b)

for best in sorted([f for f in pathlib.Path(f"/content/ray_results/parseq").iterdir() if f.is_dir()])[-1].rglob("checkpoint"):
    infer_imgs = f"/content/WordArt-V1.5/testB/images"

    # !cd {parseq_path} && conda run -n parseq python "{parseq_path}/read.py" \
    "{best}" \
    --images="{infer_imgs}" \
    --device=cuda \
    > /dev/null 2>&1

    with open(f"{parseq_path}/outputs.txt") as file:
                raw_results = file.read().strip().split("\n")

    raw_results = [line.strip().split("\t") for line in raw_results]
    raw_results = [
        tuple(
            [
                pathlib.Path(path),
                pred,
                tuple([
                    float(c)
                    for c in confidence.replace("[", "").replace("]", "").strip().split(", ")
                ])
            ]
        )
        for path, pred, confidence in raw_results
    ]

    correct = 0
    for img_path, label in zip(testB_images, testB_labels):
        for path, pred, _ in raw_results:
            if pathlib.Path(img_path).stem == pathlib.Path(path).stem:
                correct += 1 if compare(pred, label) else 0
                break

    print(f"{(best / '..' / '..').resolve().name}/{(best / '..').resolve().name}: {correct}/{len(raw_results)} ({correct / len(raw_results) * 100:.2f}%)")
# Out:
# trainable_4639b809_1_lr=0.0001_2025-10-29_20-08-52/checkpoint_000000: 2625/3000 (87.50%)
# trainable_4639b809_1_lr=0.0001_2025-10-29_20-08-52/checkpoint_000003: 2625/3000 (87.50%)
# trainable_4639b809_1_lr=0.0001_2025-10-29_20-08-52/checkpoint_000002: 2625/3000 (87.50%)
# trainable_4639b809_1_lr=0.0001_2025-10-29_20-08-52/checkpoint_000001: 2625/3000 (87.50%)
# trainable_a6b0145c_6_lr=0.0000_2025-10-29_20-11-50/checkpoint_000000: 2619/3000 (87.30%)
# trainable_bdae9971_4_lr=0.0000_2025-10-29_20-10-23/checkpoint_000000: 2619/3000 (87.30%)
# trainable_09e90a3e_7_lr=0.0000_2025-10-29_20-13-15/checkpoint_000000: 2618/3000 (87.27%)
# trainable_09e90a3e_7_lr=0.0000_2025-10-29_20-13-15/checkpoint_000003: 2624/3000 (87.47%)
# trainable_09e90a3e_7_lr=0.0000_2025-10-29_20-13-15/checkpoint_000002: 2623/3000 (87.43%)
# trainable_09e90a3e_7_lr=0.0000_2025-10-29_20-13-15/checkpoint_000001: 2623/3000 (87.43%)
# trainable_96375eb2_5_lr=0.0001_2025-10-29_20-11-08/checkpoint_000000: 2623/3000 (87.43%)
# trainable_96375eb2_5_lr=0.0001_2025-10-29_20-11-08/checkpoint_000003: 2626/3000 (87.53%)
# trainable_96375eb2_5_lr=0.0001_2025-10-29_20-11-08/checkpoint_000002: 2626/3000 (87.53%)
# trainable_96375eb2_5_lr=0.0001_2025-10-29_20-11-08/checkpoint_000001: 2626/3000 (87.53%)
# trainable_fcd49ddc_3_lr=0.0000_2025-10-29_20-09-40/checkpoint_000000: 2618/3000 (87.27%)
# trainable_fcd49ddc_3_lr=0.0000_2025-10-29_20-09-40/checkpoint_000002: 2617/3000 (87.23%)
# trainable_fcd49ddc_3_lr=0.0000_2025-10-29_20-09-40/checkpoint_000001: 2618/3000 (87.27%)
# trainable_3d6a995d_10_lr=0.0001_2025-10-29_20-18-04/checkpoint_000000: 2623/3000 (87.43%)
# trainable_3d6a995d_10_lr=0.0001_2025-10-29_20-18-04/checkpoint_000002: 2626/3000 (87.53%)
# trainable_3d6a995d_10_lr=0.0001_2025-10-29_20-18-04/checkpoint_000001: 2623/3000 (87.43%)
# trainable_445331be_2_lr=0.0000_2025-10-29_20-08-55/checkpoint_000000: 2616/3000 (87.20%)
# trainable_dc645c7f_9_lr=0.0001_2025-10-29_20-17-58/checkpoint_000000: 2628/3000 (87.60%)
# trainable_dc645c7f_9_lr=0.0001_2025-10-29_20-17-58/checkpoint_000001: 2639/3000 (87.97%)

# %%
# trainable_3d5f6386_7_lr=0.0007_2025-10-29_18-39-26/checkpoint_000000: 2613/3000 (87.10%)
# trainable_3d5f6386_7_lr=0.0007_2025-10-29_18-39-26/checkpoint_000002: 2600/3000 (86.67%)
# trainable_3d5f6386_7_lr=0.0007_2025-10-29_18-39-26/checkpoint_000001: 2600/3000 (86.67%)
# trainable_fb6c0618_5_lr=0.0002_2025-10-29_18-37-13/checkpoint_000000: 2626/3000 (87.53%)
# trainable_fb6c0618_5_lr=0.0002_2025-10-29_18-37-13/checkpoint_000002: 2626/3000 (87.53%)
# trainable_fb6c0618_5_lr=0.0002_2025-10-29_18-37-13/checkpoint_000001: 2626/3000 (87.53%)
# trainable_9418a129_6_lr=0.0001_2025-10-29_18-37-59/checkpoint_000000: 2628/3000 (87.60%)
# trainable_9418a129_6_lr=0.0001_2025-10-29_18-37-59/checkpoint_000003: 2623/3000 (87.43%)
# trainable_9418a129_6_lr=0.0001_2025-10-29_18-37-59/checkpoint_000002: 2623/3000 (87.43%)
# trainable_9418a129_6_lr=0.0001_2025-10-29_18-37-59/checkpoint_000001: 2623/3000 (87.43%)
# trainable_d5923f7d_10_lr=0.0001_2025-10-29_18-44-45/checkpoint_000000: 2629/3000 (87.63%)
# trainable_d5923f7d_10_lr=0.0001_2025-10-29_18-44-45/checkpoint_000003: 2620/3000 (87.33%)
# trainable_d5923f7d_10_lr=0.0001_2025-10-29_18-44-45/checkpoint_000002: 2619/3000 (87.30%)
# trainable_d5923f7d_10_lr=0.0001_2025-10-29_18-44-45/checkpoint_000001: 2618/3000 (87.27%)
# trainable_8be2ee24_2_lr=0.0004_2025-10-29_18-35-00/checkpoint_000000: 2621/3000 (87.37%)
# trainable_a06efcf3_4_lr=0.0004_2025-10-29_18-36-30/checkpoint_000000: 2598/3000 (86.60%)
# trainable_145f6c4f_1_lr=0.0020_2025-10-29_18-34-56/checkpoint_000000: 2492/3000 (83.07%)
# trainable_145f6c4f_1_lr=0.0020_2025-10-29_18-34-56/checkpoint_000001: 2492/3000 (83.07%)
# trainable_b56d9625_8_lr=0.0012_2025-10-29_18-40-53/checkpoint_000000: 2545/3000 (84.83%)
# trainable_421fb136_3_lr=0.0001_2025-10-29_18-35-48/checkpoint_000000: 2632/3000 (87.73%)
# trainable_421fb136_3_lr=0.0001_2025-10-29_18-35-48/checkpoint_000003: 2630/3000 (87.67%)
# trainable_421fb136_3_lr=0.0001_2025-10-29_18-35-48/checkpoint_000002: 2630/3000 (87.67%)
# trainable_421fb136_3_lr=0.0001_2025-10-29_18-35-48/checkpoint_000001: 2632/3000 (87.73%)
